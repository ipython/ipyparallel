# %%
import os
from IPython.core.interactiveshell import InteractiveShell
from IPython.display import display, Markdown, SVG, HTML, IFrame
from profiling import profiling_code
from profiling.view_profiling_results import get_latest_results_dir, get_initial_results_dir
from profiling.profiling_code_runner import profiling_tasks
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# # ipyparallel profiling results

# %% [markdown]
# ## Running profiling with py-spy

# %%
def get_results(dir_name, file_name):
    return os.path.join(dir_name, file_name)

def get_file_name(task_name, is_client):
    return f'{task_name}_{"client" if is_client else "scheduler"}.svg'

def get_latest_results(task_name, is_client=True):
    return get_results(get_latest_results_dir(), get_file_name(task_name, is_client))

def get_initial_results(task_name, is_client=True):
    return get_results(get_initial_results_dir(), get_file_name(task_name, is_client))

def display_svg(svg_file_path):
    display(IFrame(src=svg_file_path, width='100%', height=800))

# %% [markdown]
# ### Task: many_empty_tasks:

# %%
??profiling_code.profile_many_empty_tasks
# Out:
# Signature: profiling_code.profile_many_empty_tasks(lview, n, block=True)
# Docstring: <no docstring>
# Source:
# def profile_many_empty_tasks(lview, n, block=True):
#     lview.map(echo(0), [None] * n, block=block)
# File:      ~/ipyparallel_master_project/profiling/profiling_code.py
# Type:      function

# %% [markdown]
# #### Client:

# %%
display_svg(get_initial_results('many_empty_tasks'))
# Out:
#         <iframe
#             width="100%"
#             height="800"
#             src="results/profiling/initial_results_2019-10-07/many_empty_tasks_client.svg"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# #### Scheduler:

# %%
display_svg(get_initial_results('many_empty_tasks', is_client=False))
# Out:
#         <iframe
#             width="100%"
#             height="800"
#             src="results/profiling/initial_results_2019-10-07/many_empty_tasks_scheduler.svg"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ### Task: many_empty_tasks_non_blocking:

# %%
??profiling_code.profile_many_empty_tasks
# Out:
# Signature: profiling_code.profile_many_empty_tasks(lview, n, block=True)
# Docstring: <no docstring>
# Source:
# def profile_many_empty_tasks(lview, n, block=True):
#     lview.map(echo(0), [None] * n, block=block)
# File:      ~/ipyparallel_master_project/profiling/profiling_code.py
# Type:      function

# %% [markdown]
# ### Client:

# %%
display_svg(get_initial_results('many_empty_tasks_non_blocking'))
# Out:
#         <iframe
#             width="100%"
#             height="800"
#             src="results/profiling/initial_results_2019-10-07/many_empty_tasks_non_blocking_client.svg"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ### Scheduler:

# %%
display_svg(get_initial_results('many_empty_tasks_non_blocking', is_client=False))
# Out:
#         <iframe
#             width="100%"
#             height="800"
#             src="results/profiling/initial_results_2019-10-07/many_empty_tasks_non_blocking_scheduler.svg"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ### Task: tasks_with_large_data

# %%
?? profiling_code.profile_tasks_with_large_data
# Out:
# Signature:  profiling_code.profile_tasks_with_large_data(client, num_bytes)
# Docstring: <no docstring>
# Source:
# def profile_tasks_with_large_data(client, num_bytes):
#     for i in range(10):
#         client[:].apply_sync(echo(0), np.empty(num_bytes, dtype=np.int8))
# File:      ~/ipyparallel_master_project/profiling/profiling_code.py
# Type:      function

# %% [markdown]
# ### Client:

# %%
display_svg(get_initial_results('tasks_with_large_data'))
# Out:
#         <iframe
#             width="100%"
#             height="800"
#             src="results/profiling/initial_results_2019-10-07/tasks_with_large_data_client.svg"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ### Scheduler:

# %%
display_svg(get_initial_results('tasks_with_large_data', is_client=False))
# Out:
#         <iframe
#             width="100%"
#             height="800"
#             src="results/profiling/initial_results_2019-10-07/tasks_with_large_data_scheduler.svg"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ### Task: echo_many_arguments:

# %%
??profiling_code.profile_echo_many_arguments
# Out:
# Signature: profiling_code.profile_echo_many_arguments(lview, number_of_arguments)
# Docstring: <no docstring>
# Source:
# def profile_echo_many_arguments(lview, number_of_arguments):
#     lview.map(
#         lambda x: echo_many_arguments(*x),
#         [
#             tuple(np.empty(1, dtype=np.int8) for n in range(number_of_arguments))
#             for x in range(16)
#         ],
#         block=False,
#     )
# File:      ~/ipyparallel_master_project/profiling/profiling_code.py
# Type:      function

# %% [markdown]
# #### Client:

# %%
display_svg(get_initial_results('echo_many_arguments'))
# Out:
#         <iframe
#             width="100%"
#             height="800"
#             src="results/profiling/initial_results_2019-10-07/echo_many_arguments_client.svg"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# #### Scheduler:

# %%
display_svg(get_initial_results('echo_many_arguments', is_client=False))
# Out:
#         <iframe
#             width="100%"
#             height="800"
#             src="results/profiling/initial_results_2019-10-07/echo_many_arguments_scheduler.svg"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
